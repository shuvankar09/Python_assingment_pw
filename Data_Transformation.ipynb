# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvankar09/Python_assingment_pw/blob/main/Data_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
df = pd.read_csv(r"/content/employee_productivity_dataset.csv")

# %%
# Q1. Handle Missing Values (Basic Cleaning)

# Fill missing values
df["Age"].fillna(df["Age"].median(), inplace=True)

df["Salary"].fillna(df["Salary"].mean(), inplace=True)

df["Hours_Worked_Per_Week"].fillna(
    df["Hours_Worked_Per_Week"].median(),
    inplace=True
)

df["Performance_Score"].fillna(
    df["Performance_Score"].mean(),
    inplace=True
)

# Display updated dataset
print(df)
# Out:
#     Employee_ID         Name Department   Age  Gender Work_Mode   Join_Date  \
# 0          E001  Amit Sharma         IT  25.0    Male    Remote  15-01-2021
# 1          E002   Riya Patel         HR  30.0  Female    Hybrid  15-02-2020
# 2          E003  John Mathew    Finance  29.0    Male    Onsite  10-03-2022
# 3          E004  Sneha Joshi         IT  28.0  Female    Remote  22-04-2021
# 4          E005  Arjun Verma  Marketing  35.0    Male    Hybrid  18-05-2020
# ..          ...          ...        ...   ...     ...       ...         ...
# 245        E006   Neha Singh         HR  27.0  Female    Remote  01-06-2023
# 246        E007    Rahul Das    Finance  40.0    Male    Onsite  07-07-2019
# 247        E008  Pooja Mehta  Marketing  29.0  Female    Hybrid  12-08-2022
# 248        E009  Sameer Khan         IT  31.0    Male    Remote  30-09-2021
# 249        E010   Kiran Nair         HR  26.0  Female    Onsite  05-10-2023
#
#      Hours_Worked_Per_Week  Projects_Completed  Performance_Score  \
# 0                     40.0                   5             4.5000
# 1                     38.0                   4             4.0000
# 2                     45.0                   6             4.3125
# 3                     41.0                   5             4.2000
# 4                     50.0                   7             4.8000
# ..                     ...                 ...                ...
# 245                   36.0                   3             3.9000
# 246                   48.0                   8             4.7000
# 247                   42.0                   6             4.3000
# 248                   41.0                   5             4.1000
# 249                   37.0                   4             4.3125
#
#            Salary   Location
# 0    50000.000000       Pune
# 1    45000.000000     Mumbai
# 2    60000.000000  Bangalore
# 3    52000.000000      Delhi
# 4    50666.666667       Pune
# ..            ...        ...
# 245  42000.000000     Mumbai
# 246  65000.000000      Delhi
# 247  48000.000000  Bangalore
# 248  51000.000000       Pune
# 249  43000.000000     Mumbai
#
# [250 rows x 12 columns]
# /tmp/ipykernel_8082/3047860739.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# /tmp/ipykernel_8082/3047860739.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].fillna(df["Salary"].mean(), inplace=True)
# /tmp/ipykernel_8082/3047860739.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Hours_Worked_Per_Week"].fillna(
# /tmp/ipykernel_8082/3047860739.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Performance_Score"].fillna(

# %%
# Q3. One-Hot Encoding

# Apply One-Hot Encoding
df_encoded = pd.get_dummies(
    df,
    columns=["Work_Mode", "Location"]
)

# Display updated dataset
print(df_encoded)

# Check number of new columns created
print("Total Columns After Encoding:", len(df_encoded.columns))
# Out:
#     Employee_ID         Name Department   Age  Gender   Join_Date  \
# 0          E001  Amit Sharma         IT  25.0    Male  15-01-2021
# 1          E002   Riya Patel         HR  30.0  Female  15-02-2020
# 2          E003  John Mathew    Finance  29.0    Male  10-03-2022
# 3          E004  Sneha Joshi         IT  28.0  Female  22-04-2021
# 4          E005  Arjun Verma  Marketing  35.0    Male  18-05-2020
# ..          ...          ...        ...   ...     ...         ...
# 245        E006   Neha Singh         HR  27.0  Female  01-06-2023
# 246        E007    Rahul Das    Finance  40.0    Male  07-07-2019
# 247        E008  Pooja Mehta  Marketing  29.0  Female  12-08-2022
# 248        E009  Sameer Khan         IT  31.0    Male  30-09-2021
# 249        E010   Kiran Nair         HR  26.0  Female  05-10-2023
#
#      Hours_Worked_Per_Week  Projects_Completed  Performance_Score  \
# 0                     40.0                   5             4.5000
# 1                     38.0                   4             4.0000
# 2                     45.0                   6             4.3125
# 3                     41.0                   5             4.2000
# 4                     50.0                   7             4.8000
# ..                     ...                 ...                ...
# 245                   36.0                   3             3.9000
# 246                   48.0                   8             4.7000
# 247                   42.0                   6             4.3000
# 248                   41.0                   5             4.1000
# 249                   37.0                   4             4.3125
#
#            Salary  Work_Mode_Hybrid  Work_Mode_Onsite  Work_Mode_Remote  \
# 0    50000.000000             False             False              True
# 1    45000.000000              True             False             False
# 2    60000.000000             False              True             False
# 3    52000.000000             False             False              True
# 4    50666.666667              True             False             False
# ..            ...               ...               ...               ...
# 245  42000.000000             False             False              True
# 246  65000.000000             False              True             False
# 247  48000.000000              True             False             False
# 248  51000.000000             False             False              True
# 249  43000.000000             False              True             False
#
#      Location_Bangalore  Location_Delhi  Location_Mumbai  Location_Pune
# 0                 False           False            False           True
# 1                 False           False             True          False
# 2                  True           False            False          False
# 3                 False            True            False          False
# 4                 False           False            False           True
# ..                  ...             ...              ...            ...
# 245               False           False             True          False
# 246               False            True            False          False
# 247                True           False            False          False
# 248               False           False            False           True
# 249               False           False             True          False
#
# [250 rows x 17 columns]
# Total Columns After Encoding: 17

# %%
# Q4. Normalization (Min-Max Scaling)

# Create scaler object
scaler = MinMaxScaler()

# Normalize selected columns
df[["Salary", "Hours_Worked_Per_Week"]] = scaler.fit_transform(
    df[["Salary", "Hours_Worked_Per_Week"]]
)

# Display results
print(df[["Salary", "Hours_Worked_Per_Week"]])
# Out:
#        Salary  Hours_Worked_Per_Week
# 0    0.347826               0.285714
# 1    0.130435               0.142857
# 2    0.782609               0.642857
# 3    0.434783               0.357143
# 4    0.376812               1.000000
# ..        ...                    ...
# 245  0.000000               0.000000
# 246  1.000000               0.857143
# 247  0.260870               0.428571
# 248  0.391304               0.357143
# 249  0.043478               0.071429
#
# [250 rows x 2 columns]

# %%
# Q5. Standardization (Scaling)

from sklearn.preprocessing import StandardScaler

# Create StandardScaler object
scaler = StandardScaler()

# Apply Standardization
df[["Age", "Projects_Completed"]] = scaler.fit_transform(
    df[["Age", "Projects_Completed"]])

# Display transformed values
print(df[["Age", "Projects_Completed"]])
# Out:
#               Age  Projects_Completed
# 0   -1.172018e+00           -0.211604
# 1   -1.598721e-17           -0.916949
# 2   -2.344036e-01            0.493742
# 3   -4.688072e-01           -0.211604
# 4    1.172018e+00            1.199088
# ..            ...                 ...
# 245 -7.032108e-01           -1.622295
# 246  2.344036e+00            1.904433
# 247 -2.344036e-01            0.493742
# 248  2.344036e-01           -0.211604
# 249 -9.376145e-01           -0.916949
#
# [250 rows x 2 columns]

# %%
# Q6. Compare Scaling Methods

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Create scaler objects
minmax = MinMaxScaler()
standard = StandardScaler()

# Apply scaling on Salary column
df["Salary_MinMax"] = minmax.fit_transform(df[["Salary"]])

df["Salary_Standard"] = standard.fit_transform(df[["Salary"]])

# Display both results side by side
print(df[["Salary", "Salary_MinMax", "Salary_Standard"]])
# Out:
#        Salary  Salary_MinMax  Salary_Standard
# 0    0.347826       0.347826    -9.745089e-02
# 1    0.130435       0.130435    -8.283326e-01
# 2    0.782609       0.782609     1.364312e+00
# 3    0.434783       0.434783     1.949018e-01
# 4    0.376812       0.376812    -3.732632e-16
# ..        ...            ...              ...
# 245  0.000000       0.000000    -1.266862e+00
# 246  1.000000       1.000000     2.095194e+00
# 247  0.260870       0.260870    -3.898036e-01
# 248  0.391304       0.391304     4.872545e-02
# 249  0.043478       0.043478    -1.120685e+00
#
# [250 rows x 3 columns]

# %%
# Q7. Build Preprocessing Pipeline

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler
)

# Define categorical and numerical columns
categorical_cols = [
    "Gender",
    "Department",
    "Work_Mode",
    "Location"
]

numerical_cols = [
    "Age",
    "Salary",
    "Hours_Worked_Per_Week",
    "Performance_Score",
    "Projects_Completed"
]

# Create preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            StandardScaler(),
            numerical_cols
        ),
        (
            "cat",
            OneHotEncoder(),
            categorical_cols
        )
    ]
)

# Create pipeline
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor)
    ]
)

# Display pipeline
print(pipeline)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age', 'Salary',
#                                                    'Hours_Worked_Per_Week',
#                                                    'Performance_Score',
#                                                    'Projects_Completed']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Gender', 'Department',
#                                                    'Work_Mode',
#                                                    'Location'])]))])

# %%
# Q8. Apply Pipeline

# Apply pipeline on dataset
transformed_data = pipeline.fit_transform(df)

# Display transformed dataset
print(transformed_data)

# Display shape of final dataset
print("Shape of Final Dataset:", transformed_data.shape)
# Out:
# [[-1.17201808e+00 -9.74508910e-02 -4.11220496e-01 ...  0.00000000e+00
#    0.00000000e+00  1.00000000e+00]
#  [ 2.30926389e-17 -8.28332574e-01 -8.68132159e-01 ...  0.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [-2.34403615e-01  1.36431247e+00  7.31058660e-01 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [-2.34403615e-01 -3.89803564e-01  4.56911662e-02 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 2.34403615e-01  4.87254455e-02 -1.82764665e-01 ...  0.00000000e+00
#    0.00000000e+00  1.00000000e+00]
#  [-9.37614462e-01 -1.12068525e+00 -1.09658799e+00 ...  0.00000000e+00
#    1.00000000e+00  0.00000000e+00]]
# Shape of Final Dataset: (250, 18)
